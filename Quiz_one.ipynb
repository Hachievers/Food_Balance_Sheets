# %% [markdown]
# #**Importing the needed Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #**Read/Import the data into our Jupiter Notebook**

# %%
df= pd.read_csv('/content/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# #**Created a new DataFrame by grouping by column 'Element', then selected all the Years and sum total values for each attribute in column 'Element'**

# %%
df1=df.groupby(df['Element'])[['Y2014','Y2015','Y2016','Y2017','Y2018']].sum()

# %%
df1
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df.groupby(df['Item']).sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %% [markdown]
# #**Determining the number of Null rows in the column Y2014**

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %% [markdown]
# #**Determine the Correlation of Element Code for each Year**

# %%
Y2014=df['Element Code'].corr(df['Y2014'])
Y2014
# Out:
# 0.024456819495221754

# %%
Y2015=df['Element Code'].corr(df['Y2015'])
Y2015
# Out:
# 0.023889199301639956

# %%
Y2016=df['Element Code'].corr(df['Y2016'])
Y2016
# Out:
# 0.023443997584961424

# %%
Y2017=df['Element Code'].corr(df['Y2017'])
Y2017
# Out:
# 0.02425400776004575

# %%
Y2018=df['Element Code'].corr(df['Y2018'])
Y2018
# Out:
# 0.02427857195351955

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# #**Use the nunique function to determine the number of Area's in the dataset**

# %%
df2=df['Area'].nunique()

# %%
df2
# Out:
# 49

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# #**Created a new column df3 from the original DataFrame, which include rows in which column 'Element'='Protein supply quantity (g/capita/day)'**

# %%
df3=df[df['Element']=='Protein supply quantity (g/capita/day)']
df3
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 3              4   Algeria       2901               Grand Total           674
# 6              4   Algeria       2903          Vegetal Products           674
# 9              4   Algeria       2941           Animal Products           674
# 25             4   Algeria       2905  Cereals - Excluding Beer           674
# 41             4   Algeria       2511        Wheat and products           674
# ...          ...       ...        ...                       ...           ...
# 60903        181  Zimbabwe       2769   Aquatic Animals, Others           674
# 60911        181  Zimbabwe       2775            Aquatic Plants           674
# 60921        181  Zimbabwe       2928             Miscellaneous           674
# 60931        181  Zimbabwe       2680               Infant food           674
# 60941        181  Zimbabwe       2899             Miscellaneous           674
#
# ...

# %% [markdown]
# #**Created a new DataFrame with row values in Column Area='Madagascar'**

# %%
df4=df3[df3['Area']=='Madagascar']

# %% [markdown]
# #**Called the DataFrame for Inspection**

# %%
df4
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
# ...          ...         ...        ...                       ...
# 32113        129  Madagascar       2769   Aquatic Animals, Others
# 32123        129  Madagascar       2775            Aquatic Plants
# 32133        129  Madagascar       2928             Miscellaneous
# 32142        129  Madagascar       2680               Infant food
# 32152        129  Madagascar       2899             Miscellaneous
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# ...

# %% [markdown]
# #**Selected Column 'Y2015' from the the DataFrame df4 and summed it up**

# %%
df4['Y2015'].sum()
# Out:
# 173.04999999999998

# %% [markdown]
# #**Error: TypeError**

# %%
my_tuppy = (1,2,5,8)

# %%
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-e0cfa6830280> in <module>
# ----> 1 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #**Selected the column 'Y2017' and then used the describe function to determine the mean and standard deviation as well as other descriptive functions**

# %%
df['Y2017'].describe()
# Out:
# count     59437.000000
# mean        140.917765
# std        1671.862359
# min       -1582.000000
# 25%           0.000000
# 50%           0.100000
# 75%           9.000000
# max      190873.000000
# Name: Y2017, dtype: float64

# %% [markdown]
# #**Grouped by Area then selected column 'Y2017', summed the values and then sorted from Lowest to Highest**

# %%
df.groupby(df['Area'])['Y2017'].sum().sort_values(ascending=True)
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %% [markdown]
# #**Grouped by Area the selected column 'Y2017', summed the values then sorted from Highest to Lowest**

# %%
df.groupby(df['Area'])['Y2017'].sum().sort_values(ascending=False)
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %% [markdown]
# #**Called the Original DataFrame for Inspection**

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %% [markdown]
# #**Created a New DataFrame df5 to extract rows with value=Processing in the Element Column**

# %%
df5=df[df['Element']=='Processing']
df5
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 19             4   Algeria       2905  Cereals - Excluding Beer          5131
# 35             4   Algeria       2511        Wheat and products          5131
# 51             4   Algeria       2805         Rice and products          5131
# 66             4   Algeria       2513       Barley and products          5131
# 81             4   Algeria       2514        Maize and products          5131
# ...          ...       ...        ...                       ...           ...
# 60694        181  Zimbabwe       2946               Animal fats          5131
# 60717        181  Zimbabwe       2743                     Cream          5131
# 60730        181  Zimbabwe       2737        Fats, Animals, Raw          5131
# 60789        181  Zimbabwe       2948   Milk - Excluding Butter          5131
# 60803        181  Zimbabwe       2848   Milk - Excluding Butter          5131
#
# ...

# %% [markdown]
# #**Selected the 'Y2017' Column and use the sum function to sum the values**

# %%
df5['Y2017'].sum()
# Out:
# 292836.0
